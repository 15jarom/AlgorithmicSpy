# %%
# Import required libraries
import numpy as np
import pandas as pd
import os
import requests
import hvplot.pandas
from pathlib import Path
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_blobs,make_moons
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
from sklearn.metrics import r2_score
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b15cf1bd-d3c7-4d1d-8d30-8d27f5f9b517" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"96ed9dd7-eb8e-4cc1-b3e7-f5576358ce8c":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"f2bb48e78d4f4dd49a6e6f66e5670c5e","client_comm_id":"486e7d162922441fbfcadefa5a49daed"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{ ...
#   var render_items = [{"docid":"96ed9dd7-eb8e-4cc1-b3e7-f5576358ce8c","roots":{"p1002":"b15cf1bd-d3c7-4d1d-8d30-8d27f5f9b517"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# 2024-03-03 13:49:56.534377: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Read in any csv files
funds_df = pd.read_csv(Path('bill-rates-2002-2023.csv'),
                           index_col='Date',
                           parse_dates=True,
                      infer_datetime_format=True)
funds_df = funds_df.dropna()   
funds_df
# Out:
#             4 WEEKS BANK DISCOUNT  4 WEEKS COUPON EQUIVALENT  \
# Date
# 2023-12-29                   5.33                       5.44
# 2023-12-28                   5.31                       5.42
# 2023-12-27                   5.28                       5.39
# 2023-12-26                   5.27                       5.38
# 2023-12-22                   5.27                       5.38
# ...                           ...                        ...
# 2022-10-25                   3.40                       3.46
# 2022-10-24                   3.42                       3.48
# 2022-10-21                   3.42                       3.48
# 2022-10-20                   3.44                       3.50
# 2022-10-19                   3.13                       3.18
#
#             8 WEEKS BANK DISCOUNT  8 WEEKS COUPON EQUIVALENT  \
# Date
# 2023-12-29                   5.33                       5.46
# 2023-12-28                   5.29                       5.42
# 2023-12-27                   5.29                       5.42
# 2023-12-26                   5.27                       5.40
# 2023-12-22                   5.26                       5.39
# ...                           ...                        ...
# 2022-10-25                   3.62                       3.69
# 2022-10-24                   3.65                       3.72
# 2022-10-21                   3.64                       3.71
# 2022-10-20                   3.70                       3.77
# 2022-10-19                   3.52                       3.59
#
#             13 WEEKS BANK DISCOUNT  13 WEEKS COUPON EQUIVALENT  \
# Date
# 2023-12-29                    5.20                        5.35
# 2023-12-28                    5.25                        5.41
# 2023-12-27                    5.24                        5.40
# 2023-12-26                    5.25                        5.41
# 2023-12-22                    5.24                        5.39
# ...                            ...                         ...
# 2022-10-25                    3.97                        4.07
# 2022-10-24                    4.00                        4.10
# 2022-10-21                    3.90                        3.99
# 2022-10-20                    3.91                        4.00
# 2022-10-19                    3.91                        4.00
#
#             17 WEEKS BANK DISCOUNT  17 WEEKS COUPON EQUIVALENT  \
# Date
# 2023-12-29                    5.21                        5.39
# 2023-12-28                    5.22                        5.40
# 2023-12-27                    5.21                        5.39
# 2023-12-26                    5.22                        5.40
# 2023-12-22                    5.22                        5.40
# ...                            ...                         ...
# 2022-10-25                    4.12                        4.23
# 2022-10-24                    4.14                        4.26
# 2022-10-21                    4.13                        4.25
# 2022-10-20                    4.15                        4.27
# 2022-10-19                    4.15                        4.27
#
#             26 WEEKS BANK DISCOUNT  26 WEEKS COUPON EQUIVALENT  \
# Date
# 2023-12-29                    5.05                        5.26
# 2023-12-28                    5.06                        5.28
# 2023-12-27                    5.05                        5.27
# 2023-12-26                    5.06                        5.28
# 2023-12-22                    5.10                        5.32
# ...                            ...                         ...
# 2022-10-25                    4.36                        4.52
# 2022-10-24                    4.38                        4.54
# 2022-10-21                    4.29                        4.44
# 2022-10-20                    4.34                        4.50
# 2022-10-19                    4.31                        4.47
#
#             52 WEEKS BANK DISCOUNT  52 WEEKS COUPON EQUIVALENT
# Date
# 2023-12-29                    4.55                        4.79
# 2023-12-28                    4.58                        4.82
# 2023-12-27                    4.54                        4.78
# 2023-12-26                    4.58                        4.82
# 2023-12-22                    4.62                        4.86
# ...                            ...                         ...
# 2022-10-25                    4.40                        4.61
# 2022-10-24                    4.40                        4.61
# 2022-10-21                    4.38                        4.59
# 2022-10-20                    4.44                        4.65
# 2022-10-19                    4.39                        4.60
#
# [300 rows x 12 columns]

# %%
# Import API data
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi

# %%
#3
# Load .env enviroment variables/
load_dotenv('alpaca_keys.env')
# Out:
# True

# %%
#4
# Set the tickers
tickers = ['SPY','EWA','EWC','EWJ','EWU','EWZ','EWW','EZU','IWM','MCHI']

# Create the shares DataFrame
df_etf = pd.DataFrame(index=tickers)

# %%
#5
# Set Alpaca API key and secret
alpaca_api_key = os.getenv('alpaca_key')
alpaca_secret_key = os.getenv('alpaca_secret_key')

# Verify that Alpaca key and secret were correctly loaded
print(f"Alpaca Key type: {type(alpaca_api_key)}")
print(f"Alpaca Secret Key type: {type(alpaca_secret_key)}")
# Out:
# Alpaca Key type: <class 'str'>
# Alpaca Secret Key type: <class 'str'>

# %%
#6
# Create the Alpaca API object
alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")

# %%
#6a
# Create current date variable
import datetime
today = datetime.date.today()
historical = today - datetime.timedelta(days=550)

# %%
#6b
# Format current date as ISO format
# Set start and end datetimes of 18 months
start_date = pd.Timestamp(historical, tz="America/New_York").isoformat()
end_date = pd.Timestamp(today, tz="America/New_York").isoformat()

# %%
#7
# Set timeframe to 1Day for the Alpaca API
timeframe = "1Day"

# %%
#8
# Get 18 months of pricing data for ETF portfolio
df_portfolio = alpaca.get_bars(
    tickers,
    timeframe,
    start=start_date,
    end=end_date).df

df_portfolio
# Out:
#                             close     high      low  trade_count    open  \
# timestamp
# 2022-08-31 04:00:00+00:00   21.91   22.190   21.910         8650   22.14
# 2022-09-01 04:00:00+00:00   21.73   21.805   21.530         6800   21.78
# 2022-09-02 04:00:00+00:00   21.77   22.145   21.685        10128   22.02
# 2022-09-06 04:00:00+00:00   21.47   21.675   21.425        10595   21.62
# 2022-09-07 04:00:00+00:00   21.46   21.465   21.100         5996   21.10
# ...                           ...      ...      ...          ...     ...
# 2024-02-26 05:00:00+00:00  505.99  508.750  505.860       434429  508.30
# 2024-02-27 05:00:00+00:00  506.93  507.160  504.750       400260  506.70
# 2024-02-28 05:00:00+00:00  506.26  506.855  504.960       420488  505.33
# 2024-02-29 05:00:00+00:00  508.08  509.740  505.350       547158  508.07
# 2024-03-01 05:00:00+00:00  512.85  513.290  508.560       544947  508.98
#
#                              volume        vwap symbol
# timestamp
# 2022-08-31 04:00:00+00:00   3948736   22.029738    EWA
# 2022-09-01 04:00:00+00:00   3012913   21.645007    EWA
# 2022-09-02 04:00:00+00:00   5807035   21.911962    EWA
# 2022-09-06 04:00:00+00:00   2796953   21.523252    EWA
# 2022-09-07 04:00:00+00:00   2666228   21.326708    EWA
# ...                             ...         ...    ...
# 2024-02-26 05:00:00+00:00  50386738  507.079425    SPY
# 2024-02-27 05:00:00+00:00  48831828  506.231051    SPY
# 2024-02-28 05:00:00+00:00  56506634  506.035403    SPY
# 2024-02-29 05:00:00+00:00  83883970  507.940683    SPY
# 2024-03-01 05:00:00+00:00  77344853  511.227728    SPY
#
# [3770 rows x 8 columns]

# %%
# Drop time from index
df_portfolio.index = df_portfolio.index.date
df_portfolio
# Out:
#              close     high      low  trade_count    open    volume  \
# 2022-08-31   21.91   22.190   21.910         8650   22.14   3948736
# 2022-09-01   21.73   21.805   21.530         6800   21.78   3012913
# 2022-09-02   21.77   22.145   21.685        10128   22.02   5807035
# 2022-09-06   21.47   21.675   21.425        10595   21.62   2796953
# 2022-09-07   21.46   21.465   21.100         5996   21.10   2666228
# ...            ...      ...      ...          ...     ...       ...
# 2024-02-26  505.99  508.750  505.860       434429  508.30  50386738
# 2024-02-27  506.93  507.160  504.750       400260  506.70  48831828
# 2024-02-28  506.26  506.855  504.960       420488  505.33  56506634
# 2024-02-29  508.08  509.740  505.350       547158  508.07  83883970
# 2024-03-01  512.85  513.290  508.560       544947  508.98  77344853
#
#                   vwap symbol
# 2022-08-31   22.029738    EWA
# 2022-09-01   21.645007    EWA
# 2022-09-02   21.911962    EWA
# 2022-09-06   21.523252    EWA
# 2022-09-07   21.326708    EWA
# ...                ...    ...
# 2024-02-26  507.079425    SPY
# 2024-02-27  506.231051    SPY
# 2024-02-28  506.035403    SPY
# 2024-02-29  507.940683    SPY
# 2024-03-01  511.227728    SPY
#
# [3770 rows x 8 columns]

# %%
# Separate ticker data
SPY = df_portfolio[df_portfolio['symbol']=='SPY'].drop('symbol',axis=1)
EWA = df_portfolio[df_portfolio['symbol']=='EWA'].drop('symbol',axis=1)
EWC = df_portfolio[df_portfolio['symbol']=='EWC'].drop('symbol',axis=1)
EWJ = df_portfolio[df_portfolio['symbol']=='EWJ'].drop('symbol',axis=1)
EWU = df_portfolio[df_portfolio['symbol']=='EWU'].drop('symbol',axis=1)
EWZ = df_portfolio[df_portfolio['symbol']=='EWZ'].drop('symbol',axis=1)
EWW = df_portfolio[df_portfolio['symbol']=='EWW'].drop('symbol',axis=1)
EZU = df_portfolio[df_portfolio['symbol']=='EZU'].drop('symbol',axis=1)
IWM = df_portfolio[df_portfolio['symbol']=='IWM'].drop('symbol',axis=1)
MCHI = df_portfolio[df_portfolio['symbol']=='MCHI'].drop('symbol',axis=1)

# %%
# Concatenate tickers
ticker_portfolio = pd.concat([
    SPY,EWA,EWC,EWJ,EWU,EWZ,EWW,EZU,IWM,MCHI],axis=1,keys=[
    'SPY','EWA','EWC','EWJ','EWU','EWZ','EWW','EZU','IWM','MCHI'])
ticker_portfolio
# Out:
#                SPY                                                  \
#              close     high     low trade_count    open     volume
# 2022-08-31  395.18  401.240  395.04      504194  399.93   77635142
# 2022-09-01  396.42  396.780  390.04      597633  392.89   80204169
# 2022-09-02  392.24  401.555  390.33      641089  400.28  101452968
# 2024-02-26  505.99  508.750  505.86      434429  508.30   50386738
# 2024-02-27  506.93  507.160  504.75      400260  506.70   48831828
# 2024-02-28  506.26  506.855  504.96      420488  505.33   56506634
# 2024-02-29  508.08  509.740  505.35      547158  508.07   83883970
# 2024-03-01  512.85  513.290  508.56      544947  508.98   77344853
#
#                           EWA                   ...     IWM            \
#                   vwap  close    high      low  ...    open    volume
# 2022-08-31  397.187287  21.91  22.190  21.9100  ...  184.94  22457303
# 2022-09-01  393.107274  21.73  21.805  21.5300  ...  181.78  31305176
# 2022-09-02  395.334927  21.77  22.145  21.6850  ...  183.60  27901838
# 2022-09-06  391.261326  21.47  21.675  21.4250  ...  180.71  24579680
# 2022-09-07  395.364409  21.46  21.465  21.1000  ...  177.97  25383387
# ...                ...    ...     ...      ...  ...     ...       ...
# 2024-02-26  507.079425  23.83  23.905  23.7550  ...  199.69  29118221
# 2024-02-27  506.231051  23.99  24.010  23.9200  ...  203.08  32269825
# 2024-02-28  506.035403  23.71  23.725  23.6490  ...  202.44  30143882
# 2024-02-29  507.940683  23.92  24.000  23.7999  ...  205.18  40384628
# 2024-03-01  511.227728  24.19  24.200  23.9000  ...  204.53  35156920
#
#                          MCHI                                               \
#                   vwap  close     high     low trade_count   open   volume
# 2022-08-31  184.087820  49.69  50.3250  49.530       35040  49.79  6156630
# 2022-09-01  180.374139  49.22  49.3300  48.680       38620  49.15  5232575
# 2022-09-02  181.465337  48.32  48.9300  48.265       27554  48.82  3199077
# 2022-09-06  178.731439  47.39  47.9150  47.370       29728  47.90  3632619
# 2022-09-07  180.524926  48.05  48.1100  47.350       28429  47.43  3880012
# ...                ...    ...      ...     ...         ...    ...      ...
# 2024-02-26  200.940151  39.55  39.8607  39.540       24944  39.67  7433109
# 2024-02-27  203.564117  40.09  40.2000  40.015       23457  40.08  7335106
# 2024-02-28  202.930565  38.91  39.2800  38.860       21181  39.28  5005620
# 2024-02-29  204.093112  38.99  39.4000  38.920       22313  39.40  5122315
# 2024-03-01  205.428085  39.63  39.7299  39.435       19030  39.51  4125589
#
#
#                  vwap
# 2022-08-31  49.787465
# 2022-09-01  48.959277
# 2022-09-02  48.541660
# 2022-09-06  47.543434
# 2022-09-07  47.738673
# ...               ...
# 2024-02-26  39.616831
# 2024-02-27  40.099851
# 2024-02-28  38.959974
# 2024-02-29  39.105365
# 2024-03-01  39.649950
#
# [377 rows x 70 columns]

# %%
# Create a dataframe for closing prices
ticker_close = pd.DataFrame()
ticker_close['SPY Close'] = ticker_portfolio['SPY']['close']
ticker_close['EWA Close'] = ticker_portfolio['EWA']['close']
ticker_close['EWC Close'] = ticker_portfolio['EWC']['close']
ticker_close['EWJ Close'] = ticker_portfolio['EWJ']['close']
ticker_close['EWU Close'] = ticker_portfolio['EWU']['close']
ticker_close['EWZ Close'] = ticker_portfolio['EWZ']['close']
ticker_close['EWW Close'] = ticker_portfolio['EWW']['close']
ticker_close['EZU Close'] = ticker_portfolio['EZU']['close']
ticker_close['IWM Close'] = ticker_portfolio['EWA']['close']
ticker_close['MCHI Close'] = ticker_portfolio['MCHI']['close']
ticker_close = ticker_close.dropna()
ticker_close
# Out:
#             SPY Close  EWA Close  EWC Close  EWJ Close  EWU Close  EWZ Close  \
# 2022-08-31     395.18      21.91      33.69      53.59      28.91      30.52
# 2022-09-01     396.42      21.73      33.36      52.95      28.42      30.46
# 2022-09-02     392.24      21.77      33.66      52.37      28.41      30.87
# 2022-09-06     390.76      21.47      33.28      51.55      28.66      30.25
# 2022-09-07     397.78      21.46      33.67      51.47      28.63      30.53
# ...               ...        ...        ...        ...        ...        ...
# 2024-02-26     505.99      23.83      36.85      69.00      32.91      33.29
# 2024-02-27     506.93      23.99      36.76      69.18      32.93      34.08
# 2024-02-28     506.26      23.71      36.54      68.67      32.58      33.35
# 2024-02-29     508.08      23.92      36.77      69.12      32.75      33.01
# 2024-03-01     512.85      24.19      37.11      70.33      32.92      33.20
#
#             EWW Close  EZU Close  IWM Close  MCHI Close
# 2022-08-31      44.25      35.33      21.91       49.69
# 2022-09-01      44.68      34.80      21.73       49.22
# 2022-09-02      45.58      34.46      21.77       48.32
# 2022-09-06      45.00      34.56      21.47       47.39
# 2022-09-07      45.49      35.30      21.46       48.05
# ...               ...        ...        ...         ...
# 2024-02-26      66.17      48.99      23.83       39.55
# 2024-02-27      66.12      49.17      23.99       40.09
# 2024-02-28      64.89      49.07      23.71       38.91
# 2024-02-29      65.24      49.05      23.92       38.99
# 2024-03-01      65.64      49.36      24.19       39.63
#
# [377 rows x 10 columns]

# %%
# Create dataframe for training on historical data (X features)
historical_df = ticker_close['SPY Close']
historical_df
# Out:
# 2022-08-31    395.18
# 2022-09-01    396.42
# 2022-09-02    392.24
# 2022-09-06    390.76
# 2022-09-07    397.78
#                ...
# 2024-02-26    505.99
# 2024-02-27    506.93
# 2024-02-28    506.26
# 2024-02-29    508.08
# 2024-03-01    512.85
# Name: SPY Close, Length: 377, dtype: float64

# %%
# Determine correlation between SPY and ETFs
ticker_close[[
    'SPY Close','EWA Close','EWC Close','EWJ Close','EWU Close',
    'EWZ Close','EWW Close', 'EZU Close','IWM Close','MCHI Close']].corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_9af61_row0_col0, #T_9af61_row1_col1, #T_9af61_row1_col8, #T_9af61_row2_col2, #T_9af61_row3_col3, #T_9af61_row4_col4, #T_9af61_row5_col5, #T_9af61_row6_col6, #T_9af61_row7_col7, #T_9af61_row8_col1, #T_9af61_row8_col8, #T_9af61_row9_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9af61_row0_col1, #T_9af61_row0_col8 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_9af61_row0_col2 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_9af61_row0_col3 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_9af61_row0_col4, #T_9af61_row6_col1, #T_9af61_row6_col8 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_9af61_row0_col5, #T_9af61_row2_col7 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_9af61_row0_col6, #T_9af61_row3_col7 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_9af61_row0_col7, #T_9af61_row4_col1, #T_9af61_row4_col8 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_9af61_row0_col9 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_9af61_row1_col0, #T_9af61_row2_col5, #T_9af61_row8_col0 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_9af61_row1_col2, #T_9af61_row8_col2 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_9af61_row1_col3, #T_9af61_row6_col5, #T_9af61_row8_col3 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_9af61_row1_col4, #T_9af61_row8_col4 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_9af61_row1_col5, #T_9af61_row8_col5 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_9af61_row1_col6, #T_9af61_row8_col6 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_9af61_row1_col7, #T_9af61_row8_col7 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_9af61_row1_col9, #T_9af61_row8_col9 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_9af61_row2_col0, #T_9af61_row4_col3 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_9af61_row2_col1, #T_9af61_row2_col8 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_9af61_row2_col3 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_9af61_row2_col4, #T_9af61_row3_col2 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_9af61_row2_col6 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_9af61_row2_col9 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_9af61_row3_col0 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_9af61_row3_col1, #T_9af61_row3_col8, #T_9af61_row5_col6 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_9af61_row3_col4 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_9af61_row3_col5 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_9af61_row3_col6, #T_9af61_row6_col7 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_9af61_row3_col9 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_9af61_row4_col0 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_9af61_row4_col2 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_9af61_row4_col5 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_9af61_row4_col6 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_9af61_row4_col7, #T_9af61_row6_col3 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_9af61_row4_col9 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_9af61_row5_col0 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_9af61_row5_col1, #T_9af61_row5_col4, #T_9af61_row5_col8, #T_9af61_row5_col9, #T_9af61_row9_col0, #T_9af61_row9_col2, #T_9af61_row9_col3, #T_9af61_row9_col5, #T_9af61_row9_col6, #T_9af61_row9_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9af61_row5_col2 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_9af61_row5_col3 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_9af61_row5_col7 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_9af61_row6_col0 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_9af61_row6_col2 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_9af61_row6_col4 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_9af61_row6_col9 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_9af61_row7_col0 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_9af61_row7_col1, #T_9af61_row7_col8 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_9af61_row7_col2 {
#   background-color: #0569a4;
#   color: #f1f1f1;
# }
# #T_9af61_row7_col3 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_9af61_row7_col4 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_9af61_row7_col5 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_9af61_row7_col6 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_9af61_row7_col9 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_9af61_row9_col1, #T_9af61_row9_col8 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_9af61_row9_col4 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# </style>
# <table id="T_9af61">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9af61_level0_col0" class="col_heading level0 col0" >SPY Close</th>
#       <th id="T_9af61_level0_col1" class="col_heading level0 col1" >EWA Close</th>
#       <th id="T_9af61_level0_col2" class="col_heading level0 col2" >EWC Close</th>
#       <th id="T_9af61_level0_col3" class="col_heading level0 col3" >EWJ Close</th>
#       <th id="T_9af61_level0_col4" class="col_heading level0 col4" >EWU Close</th>
#       <th id="T_9af61_level0_col5" class="col_heading level0 col5" >EWZ Close</th>
#       <th id="T_9af61_level0_col6" class="col_heading level0 col6" >EWW Close</th>
#       <th id="T_9af61_level0_col7" class="col_heading level0 col7" >EZU Close</th>
#       <th id="T_9af61_level0_col8" class="col_heading level0 col8" >IWM Close</th>
#       <th id="T_9af61_level0_col9" class="col_heading level0 col9" >MCHI Close</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9af61_level0_row0" class="row_heading level0 row0" >SPY Close</th>
#       <td id="T_9af61_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9af61_row0_col1" class="data row0 col1" >0.462532</td>
#       <td id="T_9af61_row0_col2" class="data row0 col2" >0.738005</td>
#       <td id="T_9af61_row0_col3" class="data row0 col3" >0.941326</td>
#       <td id="T_9af61_row0_col4" class="data row0 col4" >0.604276</td>
#       <td id="T_9af61_row0_col5" class="data row0 col5" >0.639137</td>
#       <td id="T_9af61_row0_col6" class="data row0 col6" >0.866246</td>
#       <td id="T_9af61_row0_col7" class="data row0 col7" >0.771163</td>
#       <td id="T_9af61_row0_col8" class="data row0 col8" >0.462532</td>
#       <td id="T_9af61_row0_col9" class="data row0 col9" >-0.462902</td>
#     </tr>
#     <tr>
#       <th id="T_9af61_level0_row1" class="row_heading level0 row1" >EWA Close</th>
#       <td id="T_9af61_row1_col0" class="data row1 col0" >0.462532</td>
#       <td id="T_9af61_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9af61_row1_col2" class="data row1 col2" >0.866570</td>
#       <td id="T_9af61_row1_col3" class="data row1 col3" >0.557755</td>
#       <td id="T_9af61_row1_col4" class="data row1 col4" >0.777909</td>
#       <td id="T_9af61_row1_col5" class="data row1 col5" >0.057371</td>
#       <td id="T_9af61_row1_col6" class="data row1 col6" >0.618061</td>
#       <td id="T_9af61_row1_col7" class="data row1 col7" >0.739857</td>
#       <td id="T_9af61_row1_col8" class="data row1 col8" >1.000000</td>
#       <td id="T_9af61_row1_col9" class="data row1 col9" >0.313918</td>
#     </tr>
#     <tr>
#       <th id="T_9af61_level0_row2" class="row_heading level0 row2" >EWC Close</th>
#       <td id="T_9af61_row2_col0" class="data row2 col0" >0.738005</td>
#       <td id="T_9af61_row2_col1" class="data row2 col1" >0.866570</td>
#       <td id="T_9af61_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_9af61_row2_col3" class="data row2 col3" >0.742010</td>
#       <td id="T_9af61_row2_col4" class="data row2 col4" >0.753049</td>
#       <td id="T_9af61_row2_col5" class="data row2 col5" >0.399267</td>
#       <td id="T_9af61_row2_col6" class="data row2 col6" >0.769392</td>
#       <td id="T_9af61_row2_col7" class="data row2 col7" >0.785154</td>
#       <td id="T_9af61_row2_col8" cla

# %%
# View ticker correlation in dataframe
corr_df = ticker_close[[
    'SPY Close','EWA Close','EWC Close','EWJ Close','EWU Close',
    'EWZ Close','EWW Close', 'EZU Close','IWM Close','MCHI Close']].corr()
print(corr_df)
# Out:
#             SPY Close  EWA Close  EWC Close  EWJ Close  EWU Close  EWZ Close  \
# SPY Close    1.000000   0.462532   0.738005   0.941326   0.604276   0.639137
# EWA Close    0.462532   1.000000   0.866570   0.557755   0.777909   0.057371
# EWC Close    0.738005   0.866570   1.000000   0.742010   0.753049   0.399267
# EWJ Close    0.941326   0.557755   0.742010   1.000000   0.773662   0.458282
# EWU Close    0.604276   0.777909   0.753049   0.773662   1.000000   0.024007
# EWZ Close    0.639137   0.057371   0.399267   0.458282   0.024007   1.000000
# EWW Close    0.866246   0.618061   0.769392   0.928418   0.823963   0.429790
# EZU Close    0.771163   0.739857   0.785154   0.893956   0.946766   0.188668
# IWM Close    0.462532   1.000000   0.866570   0.557755   0.777909   0.057371
# MCHI Close  -0.462902   0.313918  -0.026199  -0.266184   0.242455  -0.622717
#
#             EWW Close  EZU Close  IWM Close  MCHI Close
# SPY Close    0.866246   0.771163   0.462532   -0.462902
# EWA Close    0.618061   0.739857   1.000000    0.313918
# EWC Close    0.769392   0.785154   0.866570   -0.026199
# EWJ Close    0.928418   0.893956   0.557755   -0.266184
# EWU Close    0.823963   0.946766   0.777909    0.242455
# EWZ Close    0.429790   0.188668   0.057371   -0.622717
# EWW Close    1.000000   0.940638   0.618061   -0.214110
# EZU Close    0.940638   1.000000   0.739857    0.034591
# IWM Close    0.618061   0.739857   1.000000    0.313918
# MCHI Close  -0.214110   0.034591   0.313918    1.000000

# %%
# Drop unnecessary columns
funds_df_2 = funds_df.drop(columns=['4 WEEKS BANK DISCOUNT','4 WEEKS COUPON EQUIVALENT',
                                           '8 WEEKS BANK DISCOUNT', '8 WEEKS COUPON EQUIVALENT',
                                           '13 WEEKS BANK DISCOUNT', '13 WEEKS COUPON EQUIVALENT',
                                           '17 WEEKS BANK DISCOUNT', '17 WEEKS COUPON EQUIVALENT',
                                           '26 WEEKS BANK DISCOUNT', '26 WEEKS COUPON EQUIVALENT', 
                                            '52 WEEKS COUPON EQUIVALENT'])
funds_df_2
# Out:
#             52 WEEKS BANK DISCOUNT
# Date
# 2023-12-29                    4.55
# 2023-12-28                    4.58
# 2023-12-27                    4.54
# 2023-12-26                    4.58
# 2023-12-22                    4.62
# ...                            ...
# 2022-10-25                    4.40
# 2022-10-24                    4.40
# 2022-10-21                    4.38
# 2022-10-20                    4.44
# 2022-10-19                    4.39
#
# [300 rows x 1 columns]

# %%
# Rename '52 WEEKS' column
funds_df_2['Fed Interest Rates'] = funds_df_2['52 WEEKS BANK DISCOUNT']
funds_df_2 = funds_df_2.drop(columns=['52 WEEKS BANK DISCOUNT'])
funds_df_2
# Out:
#             Fed Interest Rates
# Date
# 2023-12-29                4.55
# 2023-12-28                4.58
# 2023-12-27                4.54
# 2023-12-26                4.58
# 2023-12-22                4.62
# ...                        ...
# 2022-10-25                4.40
# 2022-10-24                4.40
# 2022-10-21                4.38
# 2022-10-20                4.44
# 2022-10-19                4.39
#
# [300 rows x 1 columns]

# %%
# Create a list to hold correlated etfs and respective symbols
# Create for loop to append highest correlated etfs in respective list
correlated_etfs = []
symbols = []
for index,df in corr_df.iterrows():
    if index == 'SPY Close':
        continue 
    if df['SPY Close'] >= .67:
        correlated_etfs.append(df['SPY Close'])
        symbols.append(index)
       
print(correlated_etfs)
print(symbols)
# Out:
# [0.7380052619998642, 0.9413258717279276, 0.8662462082052381, 0.771162661974003]
# ['EWC Close', 'EWJ Close', 'EWW Close', 'EZU Close']

# %%
# Set trading parameters
symbol_df = ticker_close[symbols].copy() 
symbol_df['EWJ Returns'] = symbol_df['EWJ Close'].pct_change()
symbol_df['EWW Returns'] = symbol_df['EWW Close'].pct_change()
symbol_df['EZU Returns'] = symbol_df['EZU Close'].pct_change()
symbol_df['EWC Returns'] = symbol_df['EWC Close'].pct_change()
symbol_df = symbol_df.dropna()
symbol_df
# Out:
#             EWC Close  EWJ Close  EWW Close  EZU Close  EWJ Returns  \
# 2022-09-01      33.36      52.95      44.68      34.80    -0.011943
# 2022-09-02      33.66      52.37      45.58      34.46    -0.010954
# 2022-09-06      33.28      51.55      45.00      34.56    -0.015658
# 2022-09-07      33.67      51.47      45.49      35.30    -0.001552
# 2022-09-08      34.04      52.09      45.88      35.13     0.012046
# ...               ...        ...        ...        ...          ...
# 2024-02-26      36.85      69.00      66.17      48.99    -0.000145
# 2024-02-27      36.76      69.18      66.12      49.17     0.002609
# 2024-02-28      36.54      68.67      64.89      49.07    -0.007372
# 2024-02-29      36.77      69.12      65.24      49.05     0.006553
# 2024-03-01      37.11      70.33      65.64      49.36     0.017506
#
#             EWW Returns  EZU Returns  EWC Returns
# 2022-09-01     0.009718    -0.015001    -0.009795
# 2022-09-02     0.020143    -0.009770     0.008993
# 2022-09-06    -0.012725     0.002902    -0.011289
# 2023-12-22      36.43      63.33      67.81      47.23     0.003168
# 2023-12-26      36.83      63.31      68.31      47.57    -0.000316
# 2023-12-27      36.87      63.66      68.46      47.81     0.005528
# 2023-12-28      36.70      64.04      67.96      47.41     0.005969
# 2023-12-29      36.68      64.14      67.85      47.44     0.001562
#
#             EWW Returns  EZU Returns  EWC Returns  Fed Funds Rate  \
# 2022-10-19    -0.005403    -0.014715    -0.007602            4.39
# 2022-10-20     0.005650     0.000299    -0.005107            4.44
# 2022-10-21     0.024849     0.020006     0.025345            4.38
# 2022-10-24     0.013283     0.009075    -0.002190            4.40
# 2022-10-25     0.020391     0.024949     0.016933            4.40
# ...                 ...          ...          ...             ...
# 2023-12-22    -0.000590    -0.001691     0.007467            4.62
# 2023-12-26     0.007374     0.007199     0.010980            4.58
# 2023-12-27     0.002196     0.005045     0.001086            4.54
# 2023-12-28    -0.007304    -0.008366    -0.004611            4.58
# 2023-12-29    -0.001619     0.000633    -0.000545            4.55
#
#             SPY Returns  y
# 2022-10-19    -0.007086 -1
# 2022-10-20    -0.008385 -1
# 2022-10-21     0.024301  1
# 2022-10-24     0.012237  1
# 2022-10-25     0.015969  1
# ...                 ... ..
# 2023-12-22     0.002010  0
# 2023-12-26     0.004223  1
# 2023-12-27     0.001808  0
# 2023-12-28     0.000378  0
# 2023-12-29    -0.002895 -1
#
# [299 rows x 11 columns]

# %%
# Set X (these are the initial features for neural network)
# Create a shift (lag) to verify effect of correlation on SPY Returns 
X = features_df[['EWC Close','EWJ Close','EWW Close','EZU Close',
                 'EWJ Returns','EWW Returns','EZU Returns','EWC Returns',
                 'Fed Funds Rate','SPY Returns']].shift().dropna().copy()
X.head(3)
# Out:
#             EWC Close  EWJ Close  EWW Close  EZU Close  EWJ Returns  \
# 2022-10-20      31.33      48.48      46.02      33.48    -0.006150
# 2022-10-21      31.17      48.44      46.28      33.49    -0.000825
# 2022-10-24      31.96      49.29      47.43      34.16     0.017547
#
#             EWW Returns  EZU Returns  EWC Returns  Fed Funds Rate  SPY Returns
# 2022-10-20    -0.005403    -0.014715    -0.007602            4.39    -0.007086
# 2022-10-21     0.005650     0.000299    -0.005107            4.44    -0.008385
# 2022-10-24     0.024849     0.020006     0.025345            4.38     0.024301

# %%
y = features_df['y']
y = y.iloc[1:]
y
# Out:
# 2022-10-20   -1
# 2022-10-21    1
# 2022-10-24    1
# 2022-10-25    1
# 2022-10-26   -1
#              ..
# 2023-12-22    0
# 2023-12-26    1
# 2023-12-27    0
# 2023-12-28    0
# 2023-12-29   -1
# Name: y, Length: 298, dtype: int64

# %%
# import libraries (potentially remove this block of code if redundant)
import pandas as pd
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
X_scaler = StandardScaler()
X_scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
number_inputs = 10
number_hidden_nodes = 5
neuron = Sequential()
neuron.add(Dense(units=number_hidden_nodes, input_dim=number_inputs, activation="relu"))
# Add the output layer to the model specifying the number of output neurons and activation function
neuron.add(Dense(3, activation="relu"))

# %%
neuron.summary()
# Out:
# Model: "sequential_67"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_133 (Dense)           (None, 5)                 55
#
#  dense_134 (Dense)           (None, 3)                 18
#
# =================================================================
# Total params: 73 (292.00 Byte)
# Trainable params: 73 (292.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the Sequential model
neuron.compile(loss="mean_squared_error", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 100 epochs and the training data
model = neuron.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 7/7 [==============================] - 1s 4ms/step - loss: 0.8647 - accuracy: 0.3094
# Epoch 2/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8497 - accuracy: 0.3094
# Epoch 3/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8365 - accuracy: 0.3004
# Epoch 4/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8250 - accuracy: 0.3004
# Epoch 5/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.8156 - accuracy: 0.3004
# Epoch 6/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.8067 - accuracy: 0.2960
# Epoch 7/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7988 - accuracy: 0.3004
# Epoch 8/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7919 - accuracy: 0.2960
# Epoch 9/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7862 - accuracy: 0.2915
# Epoch 10/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7819 - accuracy: 0.2825
# Epoch 11/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7777 - accuracy: 0.2780
# Epoch 12/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7733 - accuracy: 0.2825
# Epoch 13/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7709 - accuracy: 0.2825
# Epoch 14/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7686 - accuracy: 0.2960
# Epoch 15/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7662 - accuracy: 0.2915
# Epoch 16/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7649 - accuracy: 0.2870
# Epoch 17/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7630 - accuracy: 0.2915
# Epoch 18/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.7616 - accuracy: 0.2825
# Epoch 19/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7604 - accuracy: 0.2915
# Epoch 20/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7588 - accuracy: 0.2825
# Epoch 21/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7575 - accuracy: 0.2825
# Epoch 22/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7564 - accuracy: 0.2691
# Epoch 23/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7555 - accuracy: 0.2691
# Epoch 24/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7542 - accuracy: 0.2735
# Epoch 25/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7532 - accuracy: 0.2691
# Epoch 26/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7523 - accuracy: 0.2735
# Epoch 27/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7517 - accuracy: 0.2735
# Epoch 28/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7508 - accuracy: 0.2691
# Epoch 29/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7498 - accuracy: 0.2691
# Epoch 30/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7489 - accuracy: 0.2646
# Epoch 31/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7482 - accuracy: 0.2646
# Epoch 32/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7477 - accuracy: 0.2691
# Epoch 33/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7472 - accuracy: 0.2691
# Epoch 34/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7465 - accuracy: 0.2735
# Epoch 35/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7461 - accuracy: 0.2825
# Epoch 36/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7456 - accuracy: 0.2780
# Epoch 37/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7450 - accuracy: 0.2735
# Epoch 38/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7446 - accuracy: 0.2780
# Epoch 39/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7441 - accuracy: 0.2780
# Epoch 40/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7436 - accuracy: 0.2735
# Epoch 41/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7431 - accuracy: 0.2825
# Epoch 42/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7426 - accuracy: 0.2780
# Epoch 43/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7421 - accuracy: 0.2870
# Epoch 44/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7416 - accuracy: 0.2870
# Epoch 45/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7410 - accuracy: 0.2915
# Epoch 46/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7407 - accuracy: 0.2915
# Epoch 47/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7403 - accuracy: 0.2915
# Epoch 48/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7400 - accuracy: 0.2915
# Epoch 49/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7397 - accuracy: 0.2960
# Epoch 50/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7394 - accuracy: 0.2960
# Epoch 51/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7390 - accuracy: 0.3004
# Epoch 52/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7388 - accuracy: 0.3004
# Epoch 53/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7386 - accuracy: 0.2915
# Epoch 54/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7381 - accuracy: 0.3049
# Epoch 55/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7378 - accuracy: 0.3004
# Epoch 56/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7377 - accuracy: 0.3004
# Epoch 57/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7373 - accuracy: 0.2960
# Epoch 58/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7370 - accuracy: 0.2960
# Epoch 59/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7368 - accuracy: 0.3004
# Epoch 60/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7365 - accuracy: 0.3004
# Epoch 61/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7363 - accuracy: 0.3004
# Epoch 62/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7361 - accuracy: 0.2960
# Epoch 63/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7359 - accuracy: 0.2960
# Epoch 64/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7356 - accuracy: 0.2960
# Epoch 65/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7353 - accuracy: 0.2960
# Epoch 66/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7350 - accuracy: 0.2960
# Epoch 67/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7348 - accuracy: 0.2960
# Epoch 68/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7346 - accuracy: 0.2960
# Epoch 69/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7345 - accuracy: 0.2960
# Epoch 70/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7342 - accuracy: 0.2960
# Epoch 71/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7340 - accuracy: 0.2960
# Epoch 72/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7338 - accuracy: 0.2960
# Epoch 73/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7337 - accuracy: 0.2915
# Epoch 74/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7334 - accuracy: 0.2870
# Epoch 75/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7333 - accuracy: 0.2870
# Epoch 76/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7330 - accuracy: 0.2825
# Epoch 77/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7330 - accuracy: 0.2825
# Epoch 78/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7327 - accuracy: 0.2825
# Epoch 79/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7325 - accuracy: 0.2825
# Epoch 80/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7323 - accuracy: 0.2825
# Epoch 81/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7322 - accuracy: 0.2825
# Epoch 82/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7322 - accuracy: 0.2825
# Epoch 83/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7318 - accuracy: 0.2825
# Epoch 84/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7318 - accuracy: 0.2780
# Epoch 85/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7316 - accuracy: 0.2780
# Epoch 86/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7313 - accuracy: 0.2780
# Epoch 87/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7311 - accuracy: 0.2825
# Epoch 88/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7310 - accuracy: 0.2825
# Epoch 89/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7308 - accuracy: 0.2870
# Epoch 90/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7308 - accuracy: 0.2870
# Epoch 91/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7304 - accuracy: 0.2915
# Epoch 92/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7303 - accuracy: 0.2825
# Epoch 93/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7300 - accuracy: 0.2825
# Epoch 94/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7299 - accuracy: 0.2870
# Epoch 95/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7296 - accuracy: 0.2870
# Epoch 96/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7294 - accuracy: 0.2870
# Epoch 97/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7292 - accuracy: 0.2870
# Epoch 98/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7291 - accuracy: 0.2870
# Epoch 99/200
# 7/7 [==============================] - 0s 14ms/step - loss: 0.7287 - accuracy: 0.2870
# Epoch 100/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7285 - accuracy: 0.2870
# Epoch 101/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7284 - accuracy: 0.2870
# Epoch 102/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7280 - accuracy: 0.2870
# Epoch 103/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7278 - accuracy: 0.2915
# Epoch 104/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7277 - accuracy: 0.2870
# Epoch 105/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7273 - accuracy: 0.2870
# Epoch 106/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7270 - accuracy: 0.2915
# Epoch 107/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7268 - accuracy: 0.2915
# Epoch 108/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7265 - accuracy: 0.2915
# Epoch 109/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7264 - accuracy: 0.2870
# Epoch 110/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7260 - accuracy: 0.2915
# Epoch 111/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7257 - accuracy: 0.2960
# Epoch 112/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7255 - accuracy: 0.2960
# Epoch 113/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7254 - accuracy: 0.2915
# Epoch 114/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7250 - accuracy: 0.2915
# Epoch 115/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7247 - accuracy: 0.2825
# Epoch 116/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7245 - accuracy: 0.2870
# Epoch 117/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7242 - accuracy: 0.2870
# Epoch 118/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7241 - accuracy: 0.2825
# Epoch 119/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7238 - accuracy: 0.2825
# Epoch 120/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7234 - accuracy: 0.2825
# Epoch 121/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7232 - accuracy: 0.2870
# Epoch 122/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7230 - accuracy: 0.2870
# Epoch 123/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7228 - accuracy: 0.2825
# Epoch 124/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7226 - accuracy: 0.2825
# Epoch 125/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7224 - accuracy: 0.2825
# Epoch 126/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7221 - accuracy: 0.2825
# Epoch 127/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7219 - accuracy: 0.2780
# Epoch 128/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7216 - accuracy: 0.2780
# Epoch 129/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7213 - accuracy: 0.2780
# Epoch 130/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7213 - accuracy: 0.2825
# Epoch 131/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7210 - accuracy: 0.2780
# Epoch 132/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7207 - accuracy: 0.2780
# Epoch 133/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7205 - accuracy: 0.2780
# Epoch 134/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7204 - accuracy: 0.2780
# Epoch 135/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.7202 - accuracy: 0.2825
# Epoch 136/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7198 - accuracy: 0.2825
# Epoch 137/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7196 - accuracy: 0.2825
# Epoch 138/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7193 - accuracy: 0.2825
# Epoch 139/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7192 - accuracy: 0.2825
# Epoch 140/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7191 - accuracy: 0.2825
# Epoch 141/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7189 - accuracy: 0.2825
# Epoch 142/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7185 - accuracy: 0.2825
# Epoch 143/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7185 - accuracy: 0.2825
# Epoch 144/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7182 - accuracy: 0.2825
# Epoch 145/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7179 - accuracy: 0.2825
# Epoch 146/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7178 - accuracy: 0.2825
# Epoch 147/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7176 - accuracy: 0.2825
# Epoch 148/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.7173 - accuracy: 0.2825
# Epoch 149/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7171 - accuracy: 0.2825
# Epoch 150/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7171 - accuracy: 0.2825
# Epoch 151/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7169 - accuracy: 0.2825
# Epoch 152/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7166 - accuracy: 0.2870
# Epoch 153/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7165 - accuracy: 0.2870
# Epoch 154/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7164 - accuracy: 0.2870
# Epoch 155/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7161 - accuracy: 0.2870
# Epoch 156/200
# 7/7 [==============================] - 0s 12ms/step - loss: 0.7158 - accuracy: 0.2870
# Epoch 157/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7157 - accuracy: 0.2870
# Epoch 158/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7155 - accuracy: 0.2870
# Epoch 159/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7154 - accuracy: 0.2870
# Epoch 160/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.7153 - accuracy: 0.2870
# Epoch 161/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.7150 - accuracy: 0.2870
# Epoch 162/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7150 - accuracy: 0.2870
# Epoch 163/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7149 - accuracy: 0.2870
# Epoch 164/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7144 - accuracy: 0.2870
# Epoch 165/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7144 - accuracy: 0.2870
# Epoch 166/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7143 - accuracy: 0.2870
# Epoch 167/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7140 - accuracy: 0.2870
# Epoch 168/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7140 - accuracy: 0.2870
# Epoch 169/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7136 - accuracy: 0.2915
# Epoch 170/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7134 - accuracy: 0.2915
# Epoch 171/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7131 - accuracy: 0.2870
# Epoch 172/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7130 - accuracy: 0.2825
# Epoch 173/200
# 7/7 [==============================] - 0s 17ms/step - loss: 0.7127 - accuracy: 0.2870
# Epoch 174/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7125 - accuracy: 0.2915
# Epoch 175/200
# 7/7 [==============================] - 0s 11ms/step - loss: 0.7122 - accuracy: 0.2915
# Epoch 176/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7118 - accuracy: 0.2915
# Epoch 177/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7116 - accuracy: 0.2915
# Epoch 178/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7114 - accuracy: 0.2915
# Epoch 179/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7112 - accuracy: 0.2915
# Epoch 180/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7110 - accuracy: 0.2915
# Epoch 181/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7108 - accuracy: 0.2915
# Epoch 182/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.7105 - accuracy: 0.2915
# Epoch 183/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7104 - accuracy: 0.2870
# Epoch 184/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7102 - accuracy: 0.2870
# Epoch 185/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7100 - accuracy: 0.2870
# Epoch 186/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7098 - accuracy: 0.2870
# Epoch 187/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.7094 - accuracy: 0.2825
# Epoch 188/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.7093 - accuracy: 0.2870
# Epoch 189/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.7089 - accuracy: 0.2870
# Epoch 190/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7085 - accuracy: 0.2870
# Epoch 191/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7081 - accuracy: 0.2870
# Epoch 192/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7079 - accuracy: 0.2825
# Epoch 193/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7076 - accuracy: 0.2825
# Epoch 194/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7073 - accuracy: 0.2780
# Epoch 195/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7069 - accuracy: 0.2780
# Epoch 196/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7063 - accuracy: 0.2691
# Epoch 197/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7060 - accuracy: 0.2691
# Epoch 198/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7054 - accuracy: 0.2691
# Epoch 199/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7050 - accuracy: 0.2691
# Epoch 200/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.7046 - accuracy: 0.2646

# %%
# Create a DataFrame using the model history and an index parameter
model_plot = pd.DataFrame(model.history, index=range(1, len(model.history["loss"]) + 1))
# Vizualize the model plot where the y-axis displays the loss metric
model_plot.plot(y="loss")
# Out:
# <Axes: >

# %%
# Vizualize the model plot where the y-axis displays the accuracy metric
model_plot.plot(y="accuracy")
# Out:
# <Axes: >

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = neuron.evaluate(X_test_scaled, y_test, verbose=2)
# Display the evaluation results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x16fe28360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x16fe28360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 - 0s - loss: 0.7167 - accuracy: 0.2000 - 271ms/epoch - 90ms/step
# Loss: 0.7166889309883118, Accuracy: 0.20000000298023224

# %%
# Save model in JSON format
nn_json = neuron.to_json()

# Define a relative path to save the model
# The model should be saved with a .json file extension
file_path = Path("/Users/khareemhenderson/Desktop/project_2/AlgorithmicSpy/resources/model.json")

# Write the model to the the file 
with open(file_path, "w") as json_file:
    json_file.write(nn_json)

# Define a relative path to save the model weights
# The model weights should be saved with a .keras file extension
file_path = "/Users/khareemhenderson/Desktop/project_2/AlgorithmicSpy/resources/model.keras"

# Save the weights to the file path
neuron.save_weights(file_path)

# %%
# Load the model to predict values
from tensorflow.keras.models import model_from_json
# Identify the relative path of the model's location
file_path = Path('/Users/khareemhenderson/Desktop/project_2/AlgorithmicSpy/resources/model.json')

# Read in the model and save it as the variable loaded_model
with open(file_path, "r") as json_file:
    model_json = json_file.read()
loaded_model = model_from_json(model_json)

# Identify the relative path for the model's weights
file_path = "/Users/khareemhenderson/Desktop/project_2/AlgorithmicSpy/resources/model.keras"

# Load the model's weights to the variable loaded_model
loaded_model.load_weights(file_path)

# %%
# Predict values using the testing data
y_pred = loaded_model.predict(X_test_scaled)

# View the model's predictions
y_pred[:5, :]
# Out:
# 3/3 [==============================] - 0s 4ms/step
# array([[0.231971  , 0.07092226, 0.2719976 ],
#        [0.12519035, 0.3432036 , 0.11565401],
#        [0.        , 0.        , 0.        ],
#        [0.        , 0.        , 0.        ],
#        [0.06755745, 0.20356257, 0.07390679]], dtype=float32)

# %%
# Import
from sklearn.metrics import mean_squared_error

# Evaluate the model with the MSE metric
print(mean_squared_error(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[499], line 5
#       2 from sklearn.metrics import mean_squared_error
#       4 # Evaluate the model with the MSE metric
# ----> 5 print(mean_squared_error(y_test, y_pred))
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:442, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     382 def mean_squared_error(
#     383     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     384 ):
#     385     """Mean squared error regression loss.
#     386
#     387     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#     445     check_consistent_length(y_true, y_pred, sample_weight)
#     446     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_regression.py:111, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#     108     y_pred = y_pred.reshape((-1, 1))
#     110 if y_true.shape[1] != y_pred.shape[1]:
# --> 111     raise ValueError(
#     112         "y_true and y_pred have different number of output ({0}!={1})".format(
#     113             y_true.shape[1], y_pred.shape[1]
#     114         )
#     115     )
#     117 n_outputs = y_true.shape[1]
#     118 allowed_multioutput_str = ("raw_values", "uniform_average", "variance_weighted")
#
# ValueError: y_true and y_pred have different number of output (1!=3)
